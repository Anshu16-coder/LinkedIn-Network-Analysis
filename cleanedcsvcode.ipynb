# %%
import pandas as pd
import os

input_folder = r"C:\Users\ANSHU YADAV\Desktop\Assignment2\Renameaslinkedin"
output_folder = r"C:\Users\ANSHU YADAV\Desktop\Assignment2\CleanedCsvfile"
os.makedirs(output_folder, exist_ok=True)

csv_files = [f for f in os.listdir(input_folder) if f.endswith(".csv")]
fallback_encodings = ['utf-8', 'ISO-8859-1', 'latin1', 'cp1252']

for file in csv_files:
    input_path = os.path.join(input_folder, file)

    for encoding in fallback_encodings:
        try:
            # Read raw lines first to locate proper header
            with open(input_path, 'r', encoding=encoding) as f:
                lines = f.readlines()

            header_index = -1
            for i, line in enumerate(lines):
                lower_line = line.strip().lower()
                if "first name" in lower_line and "last name" in lower_line:
                    header_index = i
                    break

            if header_index == -1:
                raise ValueError("No proper header found in file.")

            # Read from detected header line
            df = pd.read_csv(input_path, skiprows=header_index, encoding=encoding)

            # Trim and normalize column names
            df.columns = [col.strip().lower() for col in df.columns]

            # Handle variations
            possible_first_names = ['first name']
            possible_last_names = ['last name']
            possible_companies = ['company']

            if not any(col in df.columns for col in possible_first_names) or not any(col in df.columns for col in possible_last_names):
                raise ValueError("Required columns not found.")

            first_name_col = next(col for col in df.columns if col in possible_first_names)
            last_name_col = next(col for col in df.columns if col in possible_last_names)
            company_col = next((col for col in df.columns if col in possible_companies), None)

            # Clean names
            df['Full Name'] = (df[first_name_col].fillna('') + ' ' + df[last_name_col].fillna('')).str.strip()
            df['Company Name'] = df[company_col].fillna('').str.strip() if company_col else ""

            # Filter and deduplicate
            final_df = df[['Full Name', 'Company Name']]
            final_df = final_df[final_df['Full Name'] != '']
            final_df.drop_duplicates(inplace=True)

            # Save cleaned CSV
            output_path = os.path.join(output_folder, file)
            final_df.to_csv(output_path, index=False)

            print(f"Cleaned and saved: {file} (encoding: {encoding})")
            break  # Stop trying other encodings once successful

        except UnicodeDecodeError as ude:
            continue
            # print(f"Failed {file} with encoding {encoding}: {ude}")
        except Exception as e:
            continue
            # print(f"Error processing {file} with encoding {encoding}: {e}")
# Out:
# Cleaned and saved: Aaditya Raj.csv (encoding: utf-8)
# Cleaned and saved: Abhishek Singh.csv (encoding: utf-8)
# Cleaned and saved: Aditya Singh.csv (encoding: utf-8)
# Cleaned and saved: Afzl Raza.csv (encoding: utf-8)
# Cleaned and saved: Ajay Jatav.csv (encoding: utf-8)
# Cleaned and saved: Ajit Yadav.csv (encoding: utf-8)
# Cleaned and saved: Akanksha Kushwaha.csv (encoding: utf-8)
# Cleaned and saved: Alok Raj.csv (encoding: utf-8)
# Cleaned and saved: Aman Adarsh.csv (encoding: utf-8)
# Cleaned and saved: Aman Singh.csv (encoding: utf-8)
# Cleaned and saved: Aman Verma.csv (encoding: utf-8)
# Cleaned and saved: Amit Kumar.csv (encoding: utf-8)
# Cleaned and saved: Anamika Kumari.csv (encoding: ISO-8859-1)
# Cleaned and saved: Anand Pandey.csv (encoding: utf-8)
# Cleaned and saved: Anand Singh.csv (encoding: utf-8)
# Cleaned and saved: ANOOP KUMAR.csv (encoding: utf-8)
# Cleaned and saved: Anshu Kumar.csv (encoding: utf-8)
# Cleaned and saved: Anuradha Tiwari.csv (encoding: ISO-8859-1)
# Cleaned and saved: Anushri Mishra.csv (encoding: utf-8)
# Cleaned and saved: Aradhya Patel.csv (encoding: utf-8)
# Cleaned and saved: Arjun Kadam.csv (encoding: utf-8)
# Cleaned and saved: Arpita Tripathi.csv (encoding: utf-8)
# Cleaned and saved: Arun Singh.csv (encoding: utf-8)
# Cleaned and saved: Aryan Saini.csv (encoding: utf-8)
# Cleaned and saved: Ashwin Yadav.csv (encoding: utf-8)
# Cleaned and saved: Ayush Kumar.csv (encoding: utf-8)
# Cleaned and saved: Ayush Yadav.csv (encoding: utf-8)
# Cleaned and saved: Bhagwan singh.csv (encoding: utf-8)
# Cleaned and saved: Bhagwati Chouhan.csv (encoding: utf-8)
# Cleaned and saved: Bhaskar Mahato.csv (encoding: utf-8)
# Cleaned and saved: Byagari PraveenKumar.csv (encoding: utf-8)
# Cleaned and saved: Challa Trivedh Kumar.csv (encoding: utf-8)
# Cleaned and saved: CHANDAN GIRI .csv (encoding: ISO-8859-1)
# Cleaned and saved: Chiranjeet Biswas.csv (encoding: utf-8)
# Cleaned and saved: Debangsu Misra.csv (encoding: utf-8)
# Cleaned and saved: Dilip Suthar.csv (encoding: utf-8)
# Cleaned and saved: Disha Sahu.csv (encoding: utf-8)
# Cleaned and saved: Divyanshi Rathour.csv (encoding: utf-8)
# Cleaned and saved: Divyanshi Sahu.csv (encoding: utf-8)
# Cleaned and saved: Ekta Kumari.csv (encoding: utf-8)
# Cleaned and saved: Gaurav Khainwar.csv (encoding: utf-8)
# Cleaned and saved: Gaurav Rathore.csv (encoding: ISO-8859-1)
# Cleaned and saved: Gaurav Tiwari.csv (encoding: utf-8)
# Cleaned and saved: Harisingh Rajpoot.csv (encoding: utf-8)
# Cleaned and saved: Harshit Chaturvedi.csv (encoding: utf-8)
# Cleaned and saved: Himanshu Kanwar Chundawat.csv (encoding: utf-8)
# Cleaned and saved: Himanshu Kumar.csv (encoding: utf-8)
# Cleaned and saved: Himanshu Srivastav.csv (encoding: utf-8)
# Cleaned and saved: Hiranya Patil.csv (encoding: utf-8)
# Cleaned and saved: Ishant Bhoyar.csv (encoding: utf-8)
# Cleaned and saved: JAMAL AKHTAR.csv (encoding: utf-8)
# Cleaned and saved: Janu Chaudhary.csv (encoding: utf-8)
# Cleaned and saved: KARANPAL SINGH RANAWAT.csv (encoding: utf-8)
# Cleaned and saved: Khushi Narwariya.csv (encoding: utf-8)
# Cleaned and saved: Kuldeep Saraswat.csv (encoding: utf-8)
# Cleaned and saved: Lakhan Rathore.csv (encoding: utf-8)
# Cleaned and saved: Maneesh Sakhwar.csv (encoding: utf-8)
# Cleaned and saved: Manish Tiwari.csv (encoding: utf-8)
# Cleaned and saved: Manoj Dewda.csv (encoding: utf-8)
# Cleaned and saved: Manoj Kharkar.csv (encoding: utf-8)
# Cleaned and saved: Mausam kumari.csv (encoding: utf-8)
# Cleaned and saved: Mayank Raj.csv (encoding: utf-8)
# Cleaned and saved: Mehtab Alam.csv (encoding: utf-8)
# Cleaned and saved: Mohd Monis.csv (encoding: utf-8)
# Cleaned and saved: Mohit Sharma.csv (encoding: utf-8)
# Cleaned and saved: Monu Rajpoot.csv (encoding: utf-8)
# Cleaned and saved: N. Arun Kumar.csv (encoding: utf-8)
# Cleaned and saved: Naman Damami.csv (encoding: utf-8)
# Cleaned and saved: Neeraj Parmar.csv (encoding: utf-8)
# Cleaned and saved: Nidhi Kumari.csv (encoding: utf-8)
# Cleaned and saved: Nikhil Chaurasiya.csv (encoding: utf-8)
# Cleaned and saved: Nirmal Mewada.csv (encoding: utf-8)
# Cleaned and saved: Ompal Yadav.csv (encoding: utf-8)
# Cleaned and saved: Pawan Kushwah.csv (encoding: utf-8)
# Cleaned and saved: Pinky Rana.csv (encoding: utf-8)
# Cleaned and saved: Pooran Singh.csv (encoding: utf-8)
# Cleaned and saved: Prabhat Patidar.csv (encoding: utf-8)
# Cleaned and saved: Prachi Dhakad.csv (encoding: utf-8)
# Cleaned and saved: Pragati Chauhan.csv (encoding: utf-8)
# Cleaned and saved: Pranjal Dubey.csv (encoding: utf-8)
# Cleaned and saved: Prem kumar.csv (encoding: utf-8)
# Cleaned and saved: Prerana Rajnag.csv (encoding: ISO-8859-1)
# Cleaned and saved: Priya Saini.csv (encoding: utf-8)
# Cleaned and saved: Priyadarshi Kumar.csv (encoding: utf-8)
# Cleaned and saved: Pushpraj Singh.csv (encoding: utf-8)
# Cleaned and saved: Rahul Kumar Verma.csv (encoding: utf-8)
# Cleaned and saved: Rahul Kumar.csv (encoding: utf-8)
# Cleaned and saved: Rajiv Kumar.csv (encoding: utf-8)
# Cleaned and saved: Ramraj Nagar.csv (encoding: utf-8)
# Cleaned and saved: Rani Kumari.csv (encoding: utf-8)
# Cleaned and saved: Ranjeet Yadav.csv (encoding: utf-8)
# Cleaned and saved: Ravi Mourya.csv (encoding: utf-8)
# Cleaned and saved: Ravi Rajput.csv (encoding: utf-8)
# Cleaned and saved: Ritik Singh.csv (encoding: utf-8)
# Cleaned and saved: Rohit kumar.csv (encoding: utf-8)
# Cleaned and saved: Rohit Malviya.csv (encoding: utf-8)
# Cleaned and saved: Sajan Kumar.csv (encoding: utf-8)
# Cleaned and saved: Samina Sultana.csv (encoding: utf-8)
# Cleaned and saved: Sandeep Kumar.csv (encoding: utf-8)
# Cleaned and saved: Sandhya Kaushal.csv (encoding: utf-8)
# Cleaned and saved: Sandhya Parmar.csv (encoding: utf-8)
# Cleaned and saved: Sarthak Mishra.csv (encoding: ISO-8859-1)
# Cleaned and saved: Satish Mahto.csv (encoding: utf-8)
# Cleaned and saved: Sauhard kumar.csv (encoding: utf-8)
# Cleaned and saved: Saurabh Bisht.csv (encoding: utf-8)
# Cleaned and saved: Shahid Ansari.csv (encoding: utf-8)
# Cleaned and saved: Shilpi Shaw.csv (encoding: utf-8)
# Cleaned and saved: Shivam Shukla.csv (encoding: utf-8)
# Cleaned and saved: Shivang Dubey.csv (encoding: utf-8)
# Cleaned and saved: Shlok Gupta.csv (encoding: utf-8)
# Cleaned and saved: Shubham Kang.csv (encoding: utf-8)
# Cleaned and saved: Shubham Kumar.csv (encoding: utf-8)
# Cleaned and saved: Sneha_Shaw.csv (encoding: utf-8)
# Cleaned and saved: Sunny Kumar.csv (encoding: utf-8)
# Cleaned and saved: Suyash Yadav.csv (encoding: utf-8)
# Cleaned and saved: Swati Kumari.csv (encoding: utf-8)
# Cleaned and saved: Ujjval Baijal.csv (encoding: utf-8)
# Cleaned and saved: Uppara Sai Maithreyi.csv (encoding: utf-8)
# Cleaned and saved: Vinay Gupta.csv (encoding: utf-8)
# Cleaned and saved: Vinay Kumar.csv (encoding: utf-8)
# Cleaned and saved: Vishal Bhardwaj.csv (encoding: utf-8)
# Cleaned and saved: Vishal Kumar.csv (encoding: utf-8)
# Cleaned and saved: Vivek kumar.csv (encoding: utf-8)
# Cleaned and saved: Vivek Singh.csv (encoding: utf-8)
# Cleaned and saved: Yuvraj Chirag.csv (encoding: utf-8)
# Cleaned and saved: Yuvraj Singh Bhati.csv (encoding: utf-8)
